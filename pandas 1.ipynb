# %%
import pandas as pd

# %%
df = pd.read_csv("HousePrices.csv")

# %%
df
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
df.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
df.tail()
# Out:
#                      date          price  bedrooms  bathrooms  sqft_living  \
# 4595  2014-07-09 00:00:00  308166.666667       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  534333.333333       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  416904.166667       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  203400.000000       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  220600.000000       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 4595      6360     1.0           0     0          4        1510
# 4596      7573     2.0           0     0          3        1460
# 4597      7014     2.0           0     0          3        3010
# 4598      6630     1.0           0     0          3        1070
# 4599      8102     2.0           0     0          4        1490
#
#       sqft_basement  yr_built  yr_renovated             street       city  \
# ...

# %%
df.dtypes  #kaun kaun se datatype hai coloumn mei
# Out:
# date              object
# price            float64
# bedrooms         float64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# street            object
# city              object
# statezip          object
# country           object
# dtype: object

# %%
df.describe() #whenever we want to see the all count,mean,missing data of numerical data
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000   4600.000000  4.600000e+03
# mean   5.519630e+05     3.400870     2.160815   2139.346957  1.485252e+04
# std    5.638347e+05     0.908848     0.783781    963.206916  3.588444e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.228750e+05     3.000000     1.750000   1460.000000  5.000750e+03
# 50%    4.609435e+05     3.000000     2.250000   1980.000000  7.683000e+03
# 75%    6.549625e+05     4.000000     2.500000   2620.000000  1.100125e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4600.000000  4600.000000  4600.000000  4600.000000  4600.000000
# mean      1.512065     0.007174     0.240652     3.451739  1827.265435
# std       0.538288     0.084404     0.778405     0.677230   862.168977
# ...

# %%
df
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
df[['date','price','bedrooms','bathrooms']]
#according to your choice you can choose selected column
# Out:
#                      date         price  bedrooms  bathrooms
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50
# ...                   ...           ...       ...        ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50
#
# [4600 rows x 4 columns]

# %%
df.dtypes == 'object'
# Out:
# date              True
# price            False
# bedrooms         False
# bathrooms        False
# sqft_living      False
# sqft_lot         False
# floors           False
# waterfront       False
# view             False
# condition        False
# sqft_above       False
# sqft_basement    False
# yr_built         False
# yr_renovated     False
# street            True
# city              True
# statezip          True
# country           True
# dtype: bool

# %%
df.dtypes == 'float64'
# Out:
# date             False
# price             True
# bedrooms          True
# bathrooms         True
# sqft_living      False
# sqft_lot         False
# floors            True
# waterfront       False
# view             False
# condition        False
# sqft_above       False
# sqft_basement    False
# yr_built         False
# yr_renovated     False
# street           False
# city             False
# statezip         False
# country          False
# dtype: bool

# %%
df[df.dtypes[df.dtypes == 'float64'].index]
#kaunse column mai kis type ka datatype hai
# Out:
#              price  bedrooms  bathrooms  floors
# 0     3.130000e+05       3.0       1.50     1.5
# 1     2.384000e+06       5.0       2.50     2.0
# 2     3.420000e+05       3.0       2.00     1.0
# 3     4.200000e+05       3.0       2.25     1.0
# 4     5.500000e+05       4.0       2.50     1.0
# ...            ...       ...        ...     ...
# 4595  3.081667e+05       3.0       1.75     1.0
# 4596  5.343333e+05       3.0       2.50     2.0
# 4597  4.169042e+05       3.0       2.50     2.0
# 4598  2.034000e+05       4.0       2.00     1.0
# 4599  2.206000e+05       3.0       2.50     2.0
#
# [4600 rows x 4 columns]

# %%
df[df.dtypes[df.dtypes == 'int64'].index]
# Out:
#       sqft_living  sqft_lot  waterfront  view  condition  sqft_above  \
# 0            1340      7912           0     0          3        1340
# 1            3650      9050           0     4          5        3370
# 2            1930     11947           0     0          4        1930
# 3            2000      8030           0     0          4        1000
# 4            1940     10500           0     0          4        1140
# ...           ...       ...         ...   ...        ...         ...
# 4595         1510      6360           0     0          4        1510
# 4596         1460      7573           0     0          3        1460
# 4597         3010      7014           0     0          3        3010
# 4598         2090      6630           0     0          3        1070
# 4599         1490      8102           0     0          4        1490
#
#       sqft_basement  yr_built  yr_renovated
# 0                 0      1955          2005
# 1               280      1921             0
# ...

# %%
df.head(10)
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
# 5  2014-05-02 00:00:00   490000.0       2.0       1.00          880      6380
# 6  2014-05-02 00:00:00   335000.0       2.0       2.00         1350      2560
# 7  2014-05-02 00:00:00   482000.0       4.0       2.50         2710     35868
# 8  2014-05-02 00:00:00   452500.0       3.0       2.50         2430     88426
# 9  2014-05-02 00:00:00   640000.0       4.0       2.00         1520      6200
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# ...

# %%
df.tail(10)
# Out:
#                      date          price  bedrooms  bathrooms  sqft_living  \
# 4590  2014-07-08 00:00:00  380680.555556       4.0       2.50         2620
# 4591  2014-07-08 00:00:00  396166.666667       3.0       1.75         1880
# 4592  2014-07-08 00:00:00  252980.000000       4.0       2.50         2530
# 4593  2014-07-08 00:00:00  289373.307692       3.0       2.50         2538
# 4594  2014-07-09 00:00:00  210614.285714       3.0       2.50         1610
# 4595  2014-07-09 00:00:00  308166.666667       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  534333.333333       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  416904.166667       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  203400.000000       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  220600.000000       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 4590      8331     2.0           0     0          3        2620
# ...

# %%
df.columns
#dataframe mei kitne column hai
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'street', 'city',
#        'statezip', 'country'],
#       dtype='object')

# %%
df[['date']]
#koi ek column ko dekhna hai
# Out:
#                      date
# 0     2014-05-02 00:00:00
# 1     2014-05-02 00:00:00
# 2     2014-05-02 00:00:00
# 3     2014-05-02 00:00:00
# 4     2014-05-02 00:00:00
# ...                   ...
# 4595  2014-07-09 00:00:00
# 4596  2014-07-09 00:00:00
# 4597  2014-07-09 00:00:00
# 4598  2014-07-10 00:00:00
# 4599  2014-07-10 00:00:00
#
# [4600 rows x 1 columns]

# %%
df[['date']][4:16:2] #jump by one
#column ko dekhna hai 4 to 16
# Out:
#                    date
# 4   2014-05-02 00:00:00
# 6   2014-05-02 00:00:00
# 8   2014-05-02 00:00:00
# 10  2014-05-02 00:00:00
# 12  2014-05-02 00:00:00
# 14  2014-05-02 00:00:00

# %%
df[['date', 'bedrooms']]
# Out:
#                      date  bedrooms
# 0     2014-05-02 00:00:00       3.0
# 1     2014-05-02 00:00:00       5.0
# 2     2014-05-02 00:00:00       3.0
# 3     2014-05-02 00:00:00       3.0
# 4     2014-05-02 00:00:00       4.0
# ...                   ...       ...
# 4595  2014-07-09 00:00:00       3.0
# 4596  2014-07-09 00:00:00       3.0
# 4597  2014-07-09 00:00:00       3.0
# 4598  2014-07-10 00:00:00       4.0
# 4599  2014-07-10 00:00:00       3.0
#
# [4600 rows x 2 columns]

# %%
df[['date', 'bedrooms']][4:17:3]
# Out:
#                    date  bedrooms
# 4   2014-05-02 00:00:00       4.0
# 7   2014-05-02 00:00:00       4.0
# 10  2014-05-02 00:00:00       3.0
# 13  2014-05-02 00:00:00       3.0
# 16  2014-05-02 00:00:00       3.0

# %%
df[['date', 'bedrooms', 'bathrooms']][4:17:3]
# Out:
#                    date  bedrooms  bathrooms
# 4   2014-05-02 00:00:00       4.0       2.50
# 7   2014-05-02 00:00:00       4.0       2.50
# 10  2014-05-02 00:00:00       3.0       1.75
# 13  2014-05-02 00:00:00       3.0       1.00
# 16  2014-05-02 00:00:00       3.0       1.50

# %%
df
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
df['Aryan'] = 0
#create a new column with all the values with 0 or something

# %%
df
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
df.insert(loc = 3, column = 'food', value = 0)
#create a column by the locationwise.

# %%
df
# Out:
#                      date         price  bedrooms  food  bathrooms  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0     0       1.50
# 1     2014-05-02 00:00:00  2.384000e+06       5.0     0       2.50
# 2     2014-05-02 00:00:00  3.420000e+05       3.0     0       2.00
# 3     2014-05-02 00:00:00  4.200000e+05       3.0     0       2.25
# 4     2014-05-02 00:00:00  5.500000e+05       4.0     0       2.50
# ...                   ...           ...       ...   ...        ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0     0       1.75
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0     0       2.50
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0     0       2.50
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0     0       2.00
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0     0       2.50
#
#       sqft_living  sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 0            1340      7912     1.5           0     0          3        1340
# ...

# %%
df.insert(loc = 3, column = 'CPU', value = 3)

# %%
df
# Out:
#                      date         price  bedrooms  CPU  food  bathrooms  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0    3     0       1.50
# 1     2014-05-02 00:00:00  2.384000e+06       5.0    3     0       2.50
# 2     2014-05-02 00:00:00  3.420000e+05       3.0    3     0       2.00
# 3     2014-05-02 00:00:00  4.200000e+05       3.0    3     0       2.25
# 4     2014-05-02 00:00:00  5.500000e+05       4.0    3     0       2.50
# ...                   ...           ...       ...  ...   ...        ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0    3     0       1.75
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0    3     0       2.50
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0    3     0       2.50
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0    3     0       2.00
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0    3     0       2.50
#
#       sqft_living  sqft_lot  floors  waterfront  ...  condition  sqft_above  \
# ...

# %% [markdown]
# #PANDAS LECTURE - 2

# %%
 import pandas as pd

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
a = df['Name'][0:10]

# %%
a
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
 type(a)
# Out:
# pandas.core.series.Series

# %%
#change the index by your choice
l = ['a1', 'a2', 'a3', 'a4', 'a5', 'a6', 'a7', 'a8', 'a9', 'a10']

# %%
pd.Series(a, index = l)
# Out:
# a1     NaN
# a2     NaN
# a3     NaN
# a4     NaN
# a5     NaN
# a6     NaN
# a7     NaN
# a8     NaN
# a9     NaN
# a10    NaN
# Name: Name, dtype: object

# %%
pd.Series(list(a), index = l) #to replace the NAN
# Out:
# a1                               Braund, Mr. Owen Harris
# a2     Cumings, Mrs. John Bradley (Florence Briggs Th...
# a3                                Heikkinen, Miss. Laina
# a4          Futrelle, Mrs. Jacques Heath (Lily May Peel)
# a5                              Allen, Mr. William Henry
# a6                                      Moran, Mr. James
# a7                               McCarthy, Mr. Timothy J
# a8                        Palsson, Master. Gosta Leonard
# a9     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# a10                  Nasser, Mrs. Nicholas (Adele Achem)
# dtype: object

# %%
m1 = pd.Series([100,200,300,400,500], index = [1,2,3,4,5])

# %%
m1
# Out:
# 1    100
# 2    200
# 3    300
# 4    400
# 5    500
# dtype: int64

# %%
m2 = pd.Series([600,700,800,900,1000], index = [1,2,3,4,5])

# %%
m2
# Out:
# 1     600
# 2     700
# 3     800
# 4     900
# 5    1000
# dtype: int64

# %%
#Concatenate both the DataFrame
m3 = pd.concat([m1,m2])

# %%
m3
# Out:
# 1     100
# 2     200
# 3     300
# 4     400
# 5     500
# 1     600
# 2     700
# 3     800
# 4     900
# 5    1000
# dtype: int64

# %%
m3[1]
# Out:
# 1    100
# 1    600
# dtype: int64

# %%
m1*m2
# Out:
# 1     60000
# 2    140000
# 3    240000
# 4    360000
# 5    500000
# dtype: int64

# %%
m1+m2
# Out:
# 1     700
# 2     900
# 3    1100
# 4    1300
# 5    1500
# dtype: int64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#delete a column
df.drop("PassengerId", axis = 1) #temprary delete
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#permanent delete
df.drop('Survived', axis = 1, inplace = True)

# %%
df
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
# ...

# %%
#rows delete

# %%
df.drop(3)
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 4              5       3                           Allen, Mr. William Henry
# 5              6       3                                   Moran, Mr. James
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
# ...

# %%
df.head()
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
df.drop(3, inplace = True) #permanent delete

# %%
df
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 4              5       3                           Allen, Mr. William Henry
# 5              6       3                                   Moran, Mr. James
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
# ...

# %%
#Name ko index banana
df.set_index('Name')
# Out:
#                                                     PassengerId  Pclass  \
# Name
# Braund, Mr. Owen Harris                                       1       3
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2       1
# Heikkinen, Miss. Laina                                        3       3
# Allen, Mr. William Henry                                      5       3
# Moran, Mr. James                                              6       3
# ...                                                         ...     ...
# Montvila, Rev. Juozas                                       887       2
# Graham, Miss. Margaret Edith                                888       1
# Johnston, Miss. Catherine Helen "Carrie"                    889       3
# Behr, Mr. Karl Howell                                       890       1
# Dooley, Mr. Patrick                                         891       3
#
#                                                        Sex   Age  SibSp  \
# Name
# ...

# %%
df
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 4              5       3                           Allen, Mr. William Henry
# 5              6       3                                   Moran, Mr. James
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
# ...

# %%
df.set_index('Name', inplace = True)
#permanent change

# %%
df
# Out:
#                                                     PassengerId  Pclass  \
# Name
# Braund, Mr. Owen Harris                                       1       3
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2       1
# Heikkinen, Miss. Laina                                        3       3
# Allen, Mr. William Henry                                      5       3
# Moran, Mr. James                                              6       3
# ...                                                         ...     ...
# Montvila, Rev. Juozas                                       887       2
# Graham, Miss. Margaret Edith                                888       1
# Johnston, Miss. Catherine Helen "Carrie"                    889       3
# Behr, Mr. Karl Howell                                       890       1
# Dooley, Mr. Patrick                                         891       3
#
#                                                        Sex   Age  SibSp  \
# Name
# ...

# %%
#reset
df.reset_index()
# Out:
#                                                   Name  PassengerId  Pclass  \
# 0                              Braund, Mr. Owen Harris            1       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...            2       1
# 2                               Heikkinen, Miss. Laina            3       3
# 3                             Allen, Mr. William Henry            5       3
# 4                                     Moran, Mr. James            6       3
# ..                                                 ...          ...     ...
# 885                              Montvila, Rev. Juozas          887       2
# 886                       Graham, Miss. Margaret Edith          888       1
# 887           Johnston, Miss. Catherine Helen "Carrie"          889       3
# 888                              Behr, Mr. Karl Howell          890       1
# 889                                Dooley, Mr. Patrick          891       3
#
# ...

# %%
#Create a dataframe by a dictionary
d = {'key1' : [1,2,3,4,5],
     'key2' : [6,7,8,9,10],
     'key3' : [11,12,13,14,15]
    }

# %%
print(d)
# Out:
# {'key1': [1, 2, 3, 4, 5], 'key2': [6, 7, 8, 9, 10], 'key3': [11, 12, 13, 14, 15]}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     1     6    11
# 1     2     7    12
# 2     3     8    13
# 3     4     9    14
# 4     5    10    15

# %%
df1 = pd.read_csv("HousePrices.csv")

# %%
df1
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
#Delete NAN from the dataframe
df1.dropna()
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
df1
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
#permanent NAN delete
df1.dropna(inplace = True)

# %%
df1
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
df2 = pd.read_csv("HousePrices.csv")

# %%
df2
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
#delete column NAN
df2.dropna(axis = 1)
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
df2.dropna(axis = 1, inplace = True)

# %%
df2
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
df3 = pd.read_csv("HousePrices.csv")

# %%
df3
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
#fill the NAN value by your choice
df.fillna("Aryan")
# Out:
#                                                     PassengerId  Pclass  \
# Name
# Braund, Mr. Owen Harris                                       1       3
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2       1
# Heikkinen, Miss. Laina                                        3       3
# Allen, Mr. William Henry                                      5       3
# Moran, Mr. James                                              6       3
# ...                                                         ...     ...
# Montvila, Rev. Juozas                                       887       2
# Graham, Miss. Margaret Edith                                888       1
# Johnston, Miss. Catherine Helen "Carrie"                    889       3
# Behr, Mr. Karl Howell                                       890       1
# Dooley, Mr. Patrick                                         891       3
#
#                                                        Sex    Age  SibSp  \
# Name
# ...

# %%
df3.fillna("Aryan", inplace = True)

# %%
df3
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...
